# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sample = pd.read_csv("sample_submission.csv")
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1205 entries, 0 to 1204
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   일자              1205 non-null   object
#  1   요일              1205 non-null   object
#  2   본사정원수           1205 non-null   int64
#  3   본사휴가자수          1205 non-null   int64
#  4   본사출장자수          1205 non-null   int64
#  5   본사시간외근무명령서승인건수  1205 non-null   int64
#  6   현본사소속재택근무자수     1205 non-null   float64
#  7   조식메뉴            1205 non-null   object
#  8   중식메뉴            1205 non-null   object
#  9   석식메뉴            1205 non-null   object
#  10  중식계             1205 non-null   float64
#  11  석식계             1205 non-null   float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 113.1+ KB

# %%
train.head(5)
# Out:
#            일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 0  2016-02-01  월   2601      50     150             238          0.0
# 1  2016-02-02  화   2601      50     173             319          0.0
# 2  2016-02-03  수   2601      56     180             111          0.0
# 3  2016-02-04  목   2601     104     220             355          0.0
# 4  2016-02-05  금   2601     278     181              34          0.0
#
#                                                 조식메뉴  \
# 0  모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1  모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2  모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3  모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4  모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
#
#                                                 중식메뉴  \
# 0  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 오징어찌개  쇠불고기 (쇠고기:호주산) 계란찜 ...
# 1  쌀밥/잡곡밥 (쌀,현미흑미:국내산) 김치찌개  가자미튀김  모둠소세지구이  마늘쫑무...
# 2  카레덮밥 (쌀,현미흑미:국내산) 팽이장국  치킨핑거 (닭고기:국내산) 쫄면야채무침 ...
# ...

# %%
train["조식메뉴"][0].split()
# Out:
# ['모닝롤/찐빵',
#  '우유/두유/주스',
#  '계란후라이',
#  '호두죽/쌀밥',
#  '(쌀:국내산)',
#  '된장찌개',
#  '쥐어채무침',
#  '포기김치',
#  '(배추,고추가루:국내산)']

# %%
A = []
for i in range(len(train)):
    B = train["조식메뉴"][i].split()
    for j in B:
        A.append(j)

# %%
print(len(A))
len(set(A))
B = list(set(A))
# Out:
# 10747

# %%
train["조식메뉴"]
# Out:
# 0       모닝롤/찐빵  우유/두유/주스 계란후라이  호두죽/쌀밥 (쌀:국내산) 된장찌개  쥐...
# 1       모닝롤/단호박샌드  우유/두유/주스 계란후라이  팥죽/쌀밥 (쌀:국내산) 호박젓국찌...
# 2       모닝롤/베이글  우유/두유/주스 계란후라이  표고버섯죽/쌀밥 (쌀:국내산) 콩나물국...
# 3       모닝롤/토마토샌드  우유/두유/주스 계란후라이  닭죽/쌀밥 (쌀,닭:국내산) 근대국...
# 4       모닝롤/와플  우유/두유/주스 계란후라이  쇠고기죽/쌀밥 (쌀:국내산) 재첩국  방...
#                               ...
# 1200    모닝롤/페퍼로니피자 우유/주스 계란후라이/찐계란 크루통크림스프/흑미밥 아귀지리 마늘...
# 1201    모닝롤/생크림단팥빵 우유/주스 계란후라이/찐계란 누룽지탕/흑미밥 떡국 해물땡굴소스볶...
# 1202    모닝롤/BLT샌드위치 우유/주스 계란후라이/찐계란 흑임자죽/흑미밥 바지락살국 두부조...
# 1203    모닝롤/호박고구마오븐구이 우유/주스 계란후라이/찐계란 누룽지탕/흑미밥 감자양파국 분...
# 1204    모닝롤/야채샌드 우유/주스 계란후라이/찐계란 참치죽/흑미밥 홍합탕 애호박새우젓볶음 ...
# Name: 조식메뉴, Length: 1205, dtype: object

# %%
len(B)
# Out:
# 840

# %%
train[train["조식메뉴"].str.contains(B[1])]
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 110  2016-07-14  목   2643      84     252             308          0.0
# 658  2018-10-18  목   2805      74     299             175          0.0
#
#                                                   조식메뉴  \
# 110  모닝롤/햄치즈샌드  우유/주스 계란후라이  새송이죽/쌀밥 (쌀:국내산) 새알미역국 ...
# 658  모닝롤/토마토샌드  우유/주스 계란후라이 야채죽/쌀밥 (쌀:국내산) 새알미역국  연...
#
#                                                   중식메뉴  \
# 110  쌀밥/잡곡밥 (쌀:국내산) 배추된장국  매운주꾸미볶음  동태전  브로컬리두부무침  ...
# 658  쌀밥/잡곡밥 (쌀:국내산) 감자국  김치제육볶음  해물파전  브로컬리들깨찜  열무김...
#
#                                                   석식메뉴    중식계    석식계
# 110  멸치주먹밥 (쌀:국내산) 물냉면  과일샐러드  무초절임  찐옥수수  포기김치 (김치...  781.0  550.0
# 658  유부초밥 (쌀:국내산) 짬뽕  탕수육  생과일플레인샐러드  단무지  포기김치 (김치...  857.0  532.0

# %%
train[train["조식메뉴"].str.contains(B[0])]
# Out:
#              일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 647  2018-09-18  화   2763      67     289             446          0.0
#
#                                                   조식메뉴  \
# 647  모닝롤/피자샌드  우유/주스 스크램블에그 잣죽/쌀밥 (쌀:국내산) 열무된장국  연근...
#
#                                                   중식메뉴  \
# 647  쌀밥/잡곡밥 (쌀:국내산) 닭개장  류산슬  김치전  아삭고추무침  포기김치 (김치...
#
#                                                   석식메뉴    중식계    석식계
# 647  유부초밥 (쌀:국내산) 우동  순대야채볶음  참치샐러드  음료  포기김치 (김치:국...  946.0  597.0

# %%
for i in range(len(B)):
    if B[i] == "모닝롤/크림치즈프레즐":
        print(i)
# Out:
# 152

# %%
B
# Out:
# ['모닝롤/피자샌드',
#  '새알미역국',
#  '유부김치국',
#  '모닝롤/트위스터버거',
#  '토란탕',
#  '모닝롤/미니케익',
#  '모닝롤/살라미샌드위치',
#  '미니새송이볶음',
#  '도토리묵무침',
#  '콥샐러드/양상추샐러드',
#  '팥죽/쌀밥',
#  '미역소고기죽/흑미밥',
#  '해물죽/쌀밥',
#  '사각어묵볶음',
#  '새알팥죽/흑미밥',
#  '김가루실파무침',
#  '통마늘너비아니조림',
#  '열무된장나물',
#  '쑥국',
#  '모닝롤/와플',
#  '참나물땅콩무침',
#  '모닝롤/참치샌드',
#  '쑥갓무침',
#  '배추겉절이',
#  '브로콜리맛살볶음',
#  '크로아상샌드위치',
#  '보리누룽지탕/쌀밥',
#  '시래기지짐',
#  '고구마순볶음',
#  '소시지볶음',
#  '(배추,고춧가루:국산)',
#  '가지양파나물',
#  '오이보트샐러드',
#  '연두부샐러드/양상추샐러드',
#  '명엽채볶음',
#  '맑은콩나물국',
#  '양념깻잎지',
#  '모닝롤/시금치핫케익',
#  '(쌀:국내산,쇠고기:호주)',
#  '멸치캐슈넛볶음',
#  '모닝롤/대만샌드위치',
#  '모닝롤/증편',
#  '콩나물간장조림',
#  '알타리김치',
#  '모닝롤/흑미쌀찐빵',
#  '볼어묵조림',
#  '냉이국',
#  '오색떡국',
#  '와플/모닝에그빵',
#  '흑임자죽/흑미밥',
#  '옹심이만두떡국',
#  '무채국',
#  '애호박새우젓볶음',
#  '어묵꽈리고추볶음',
#  '베이컨감자볶음',
#  '가지두반장볶음',
#  '꽈리고추찜',
#  '톳무침',
#  '골뱅이무침',
#  '(배추:국내산,고춧가루:중국산)',
#  '두부조림',
#  '호박숙',
#  '파래무침',
#  '크림누룽지탕/쌀밥',
#  '동전문어조림',
#  '매운감자국',
#  '방풍나물',
#  '감자채햄볶음',
#  '어묵토마토조림',
#  '모닝롤/와플&생크림',
#  '치커리무침',
#  '모닝롤/치킨샌드',
# ...

# %%
#B.remove("없이)")
요리 = B

# %%
count = []
for i in B:
    x = A.count(i)
    count.append(x)

# %%
요리 = np.array(요리)

# %%
data = pd.DataFrame(요리)

# %%
data.rename(columns={0: "요리"}, inplace = True)
data["갯수"] = count
data.sort_values(by = "갯수", ascending = False)
# Out:
#               요리    갯수
# 755         포기김치  1192
# 573        우유/주스  1172
# 774      (쌀:국내산)   995
# 193     (김치:국내산)   930
# 307        계란후라이   911
# ..           ...   ...
# 365    얼큰낙지죽/흑미밥     1
# 363        청경채무침     1
# 362  우유/주스/아메리카노     1
# 361       메추리알조림     1
# 839        어묵매운국     1
#
# [840 rows x 2 columns]

# %%
sum(data["갯수"])
# Out:
# 10747

# %%
len(A)
# Out:
# 10747

# %%
data
# Out:
#              요리  갯수
# 0      모닝롤/피자샌드   1
# 1         새알미역국   2
# 2         유부김치국   2
# 3    모닝롤/트위스터버거   1
# 4           토란탕   4
# ..          ...  ..
# 835      새우살미역국   4
# 836       도라지나물  11
# 837  모닝롤/사과샌드위치   1
# 838        우엉조림   7
# 839       어묵매운국   1
#
# [840 rows x 2 columns]

# %%
data.sort_values(by = "갯수", ascending = False)

data[data["갯수"] ==4]
# Out:
#              요리  갯수
# 0      모닝롤/피자샌드   1
# 1         새알미역국   2
# 2         유부김치국   2
# 3    모닝롤/트위스터버거   1
# 5      모닝롤/미니케익   1
# ..          ...  ..
# 832        돈사태찜   1
# 833  모닝롤/길거리토스트   2
# 834     비엔나채소볶음   1
# 837  모닝롤/사과샌드위치   1
# 839       어묵매운국   1
#
# [583 rows x 2 columns]

# %%
data[data["갯수"] ==0]
# Out:
# Empty DataFrame
# Columns: [요리, 갯수]
# Index: []

# %%
data[data["갯수"] ==1]
# Out:
#               요리  갯수
# 0       모닝롤/피자샌드   1
# 3     모닝롤/트위스터버거   1
# 5       모닝롤/미니케익   1
# 6    모닝롤/살라미샌드위치   1
# 7        미니새송이볶음   1
# ..           ...  ..
# 831  모닝롤/햄에그샌드위치   1
# 832         돈사태찜   1
# 834      비엔나채소볶음   1
# 837   모닝롤/사과샌드위치   1
# 839        어묵매운국   1
#
# [401 rows x 2 columns]

# %%
data[data["갯수"] ==2]
# Out:
#               요리  갯수
# 1          새알미역국   2
# 2          유부김치국   2
# 8         도토리묵무침   2
# 9    콥샐러드/양상추샐러드   2
# 20       참나물땅콩무침   2
# ..           ...  ..
# 819      오징어젓갈무침   2
# 821   모닝롤/인기가요샌드   2
# 822          자반김   2
# 830    모닝롤/크로크무슈   2
# 833   모닝롤/길거리토스트   2
#
# [116 rows x 2 columns]

# %%
data[data["갯수"] ==3]
# Out:
#              요리  갯수
# 18           쑥국   3
# 27        시래기지짐   3
# 34        명엽채볶음   3
# 36        양념깻잎지   3
# 40   모닝롤/대만샌드위치   3
# ..          ...  ..
# 786      조랭이미역국   3
# 801      달래된장찌개   3
# 806     시금치죽/쌀밥   3
# 808        버섯볶음   3
# 829    모닝롤/감자샌드   3
#
# [66 rows x 2 columns]

# %%
data[data["갯수"] ==4]
# Out:
#                  요리  갯수
# 4               토란탕   4
# 15          김가루실파무침   4
# 38   (쌀:국내산,쇠고기:호주)   4
# 44        모닝롤/흑미쌀찐빵   4
# 45            볼어묵조림   4
# 46              냉이국   4
# 55          가지두반장볶음   4
# 66             방풍나물   4
# 90            순두부백탕   4
# 144          숙주나물무침   4
# 170      모닝롤/오렌지케익빵   4
# 173             무나물   4
# 230           들깨버섯국   4
# 238           김실파무침   4
# 244         오곡죽/흑미밥   4
# 326          콩가루배추국   4
# 364             콩자반   4
# 379         조랭이떡미역국   4
# 429           황태해장국   4
# 431           순두부찌개   4
# 440        단호박죽/흑미밥   4
# 441        모닝롤/소보루빵   4
# 476             만두국   4
# 484        마늘쫑건새우볶음   4
# 493          영양부추생채   4
# 554        모닝롤/녹차호떡   4
# 596             깍두기   4
# 656         수삼닭죽/쌀밥   4
# 688          시래기된장국   4
# 697             콩조림   4
# 702           들깨무채국   4
# 714          모닝롤/호떡   4
# 715           볼어묵볶음   4
# 717     모닝롤/BLT샌드위치   4
# 738            미역나물   4
# 779           애호박볶음   4
# 816           진미채볶음   4
# ...

# %%
data[data["갯수"] ==5]
# Out:
#                     요리  갯수
# 59   (배추:국내산,고춧가루:중국산)   5
# 73                오이생채   5
# 75               근대된장국   5
# 117            새송이버섯볶음   5
# 183            누룽지/흑미밥   5
# 205           크랜베리멸치볶음   5
# 226             두부양념조림   5
# 264             얼갈이된장국   5
# 281            녹두죽/흑미밥   5
# 451         모닝롤/시금치팬케익   5
# 500             연근땅콩조림   5
# 517    (배추:국산,고추가루:중국)   5
# 521              봄동된장국   5
# 547           건새우마늘쫑볶음   5
# 555             참치김치찌개   5
# 576              매생이굴국   5
# 592             호박새우젓국   5
# 608              감자양파국   5
# 654             잣죽/흑미밥   5
# 661              새송이볶음   5
# 668             올챙이만두국   5
# 735              청포묵무침   5
# 773           고구마죽/흑미밥   5
# 813             올갱이아욱국   5
# 828          (황태:러시아산)   5

# %%
data[data["갯수"] >6]
# Out:
#                요리  갯수
# 10          팥죽/쌀밥  40
# 12         해물죽/쌀밥  37
# 19         모닝롤/와플  41
# 21       모닝롤/참치샌드  42
# 30   (배추,고춧가루:국산)   8
# ..            ...  ..
# 811       모닝롤/베이글  39
# 825        동전쥐포무침   7
# 826     모닝롤/단호박샌드  18
# 836         도라지나물  11
# 838          우엉조림   7
#
# [177 rows x 2 columns]

# %%
train.sort_values(by = "중식계", ascending = False)
# Out:
#               일자 요일  본사정원수  본사휴가자수  본사출장자수  본사시간외근무명령서승인건수  현본사소속재택근무자수  \
# 735   2019-02-11  월   2806      67     159             758          0.0
# 490   2018-01-29  월   2655      70     192             454          0.0
# 1188  2021-01-04  월   2983      92      91             490        340.0
# 495   2018-02-05  월   2707      76     213             560          0.0
# 986   2020-02-17  월   2872      74     196             722          0.0
# ...          ... ..    ...     ...     ...             ...          ...
# 1129  2020-09-28  월   3132     985     188              81        142.0
# 955   2019-12-31  화   3111     709     149              22          0.0
# 709   2018-12-31  월   2846    1085     132              28          0.0
# 469   2017-12-28  목   2665     240     260              55          0.0
# 705   2018-12-24  월   2846     894     159              26          0.0
#
#                                                    조식메뉴  \
# ...
